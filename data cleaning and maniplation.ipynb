# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\navan\OneDrive\Desktop\PROJECT\data analyst project\banglore11.csv")
df1=pd.read_csv(r"C:\Users\navan\OneDrive\Desktop\PROJECT\data analyst project\Tirupati.csv")
df2=pd.read_csv(r"C:\Users\navan\OneDrive\Desktop\PROJECT\data analyst project\chennai.csv")
df3=pd.read_csv(r"C:\Users\navan\OneDrive\Desktop\PROJECT\data analyst project\Hyderabad.csv")
merged_data=pd.concat([df,df1,df2,df3],ignore_index=True)
merged_data.head()
# Out:
#                                  Hotel_Name                 Location   Price  \
# 0                Itsy Hotels Shree Comforts    HSR Layout, Bangalore   3,037
# 1         The Leela Bhartiya City Bengaluru                Bangalore  23,500
# 2   Olive Zip Kalyan Nagar by Embassy Group  Kalyan Nagar, Bangalore   3,562
# 3  Olive Hotel Indiranagar by Embassy Group   Indiranagar, Bangalore   5,656
# 4              Radisson Blu Atria Bengaluru                Bangalore  15,900
#
#               Sharing                        Facilities  Review  Riview_count  \
# 0  2 nights, 2 adults  [Sanitized] Standard Double Room     7.3          84.0
# 1  2 nights, 2 adults                       Deluxe Room     9.0         676.0
# 2  2 nights, 2 adults              Standard Double Room     7.3         464.0
# 3  2 nights, 2 adults                Budget Double Room     7.6        1403.0
# 4  2 nights, 2 adults                     Superior Room     8.0        1712.0
#
#    star_count  Unnamed: 0
# ...

# %%
merged_data.tail()
# Out:
#                                             Hotel_Name               Location  \
# 97                    Super Hotel O Madhapur VIP Hills  HITEC City, Hyderabad
# 98                              Hotel Imperial Classic              Hyderabad
# 99                              The Purple Leaf Hotels              Hyderabad
# 100                                 The Golkonda Hotel              Hyderabad
# 101  FabHotel Royal Residency II - Nr Metro Station...              Hyderabad
#
#       Price             Sharing                  Facilities  Review  \
# 97    2,233  2 nights, 2 adults         Classic Triple Room     5.5
# 98    3,500  2 nights, 2 adults       Executive Double Room     7.3
# 99    6,500  2 nights, 2 adults  Deluxe Double or Twin Room     7.2
# 100  15,448  2 nights, 2 adults          Premium Twin Room      7.3
# 101   4,190  2 nights, 2 adults          Deluxe Double Room     7.7
#
#      Riview_count  star_count  Unnamed: 0
# 97           44.0         4.0         NaN
# ...

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Hotel_Name    102 non-null    object
#  1   Location      102 non-null    object
#  2   Price         102 non-null    object
#  3   Sharing       102 non-null    object
#  4   Facilities    102 non-null    object
#  5   Review        97 non-null     float64
#  6   Riview_count  97 non-null     float64
#  7   star_count    85 non-null     float64
#  8   Unnamed: 0    25 non-null     float64
# dtypes: float64(4), object(5)
# memory usage: 7.3+ KB

# %%
merged_data.dtypes
# Out:
# Hotel_Name       object
# Location         object
# Price            object
# Sharing          object
# Facilities       object
# Review          float64
# Riview_count    float64
# star_count      float64
# Unnamed: 0      float64
# dtype: object

# %%
merged_data.sample()
# Out:
#                           Hotel_Name   Location   Price             Sharing  \
# 1  The Leela Bhartiya City Bengaluru  Bangalore  23,500  2 nights, 2 adults
#
#     Facilities  Review  Riview_count  star_count  Unnamed: 0
# 1  Deluxe Room     9.0         676.0         5.0         NaN

# %%
merged_data.describe()
# Out:
#           Review  Riview_count  star_count  Unnamed: 0
# count  97.000000     97.000000   85.000000   25.000000
# mean    7.595876    583.659794    3.670588   12.000000
# std     0.888927    579.756215    0.930799    7.359801
# min     4.900000      2.000000    2.000000    0.000000
# 25%     7.100000    137.000000    3.000000    6.000000
# 50%     7.600000    344.000000    3.000000   12.000000
# 75%     8.100000    894.000000    5.000000   18.000000
# max    10.000000   2373.000000    5.000000   24.000000

# %%
merged_data.isna().sum()
# Out:
# Hotel_Name       0
# Location         0
# Price            0
# Sharing          0
# Facilities       0
# Review           5
# Riview_count     5
# star_count      17
# Unnamed: 0      77
# dtype: int64

# %%
DD=merged_data.fillna(0)
DD
# Out:
#                                             Hotel_Name  \
# 0                           Itsy Hotels Shree Comforts
# 1                    The Leela Bhartiya City Bengaluru
# 2              Olive Zip Kalyan Nagar by Embassy Group
# 3             Olive Hotel Indiranagar by Embassy Group
# 4                         Radisson Blu Atria Bengaluru
# ..                                                 ...
# 97                    Super Hotel O Madhapur VIP Hills
# 98                              Hotel Imperial Classic
# 99                              The Purple Leaf Hotels
# 100                                 The Golkonda Hotel
# 101  FabHotel Royal Residency II - Nr Metro Station...
#
#                     Location   Price             Sharing  \
# 0      HSR Layout, Bangalore   3,037  2 nights, 2 adults
# 1                  Bangalore  23,500  2 nights, 2 adults
# 2    Kalyan Nagar, Bangalore   3,562  2 nights, 2 adults
# 3     Indiranagar, Bangalore   5,656  2 nights, 2 adults
# ...

# %%
DD['city'] = DD['Location'].str.split(',').str[-1].str.strip()
DD
# Out:
#                                             Hotel_Name  \
# 0                           Itsy Hotels Shree Comforts
# 1                    The Leela Bhartiya City Bengaluru
# 2              Olive Zip Kalyan Nagar by Embassy Group
# 3             Olive Hotel Indiranagar by Embassy Group
# 4                         Radisson Blu Atria Bengaluru
# ..                                                 ...
# 97                    Super Hotel O Madhapur VIP Hills
# 98                              Hotel Imperial Classic
# 99                              The Purple Leaf Hotels
# 100                                 The Golkonda Hotel
# 101  FabHotel Royal Residency II - Nr Metro Station...
#
#                     Location   Price             Sharing  \
# 0      HSR Layout, Bangalore   3,037  2 nights, 2 adults
# 1                  Bangalore  23,500  2 nights, 2 adults
# 2    Kalyan Nagar, Bangalore   3,562  2 nights, 2 adults
# 3     Indiranagar, Bangalore   5,656  2 nights, 2 adults
# ...

# %%
DD['Price'] = DD['Price'].astype(str)
DD['Price'] = DD['Price'].str.replace(',', '').astype(float)
DD
# Out:
#                                             Hotel_Name  \
# 0                           Itsy Hotels Shree Comforts
# 1                    The Leela Bhartiya City Bengaluru
# 2              Olive Zip Kalyan Nagar by Embassy Group
# 3             Olive Hotel Indiranagar by Embassy Group
# 4                         Radisson Blu Atria Bengaluru
# ..                                                 ...
# 97                    Super Hotel O Madhapur VIP Hills
# 98                              Hotel Imperial Classic
# 99                              The Purple Leaf Hotels
# 100                                 The Golkonda Hotel
# 101  FabHotel Royal Residency II - Nr Metro Station...
#
#                     Location    Price             Sharing  \
# 0      HSR Layout, Bangalore   3037.0  2 nights, 2 adults
# 1                  Bangalore  23500.0  2 nights, 2 adults
# 2    Kalyan Nagar, Bangalore   3562.0  2 nights, 2 adults
# 3     Indiranagar, Bangalore   5656.0  2 nights, 2 adults
# ...

# %%
DD.isna().sum()
# Out:
# Hotel_Name      0
# Location        0
# Price           0
# Sharing         0
# Facilities      0
# Review          0
# Riview_count    0
# star_count      0
# Unnamed: 0      0
# city            0
# dtype: int64

# %%
DD = DD.rename(columns={'Riview_count': 'Review_count'})
DD
# Out:
#                                             Hotel_Name  \
# 0                           Itsy Hotels Shree Comforts
# 1                    The Leela Bhartiya City Bengaluru
# 2              Olive Zip Kalyan Nagar by Embassy Group
# 3             Olive Hotel Indiranagar by Embassy Group
# 4                         Radisson Blu Atria Bengaluru
# ..                                                 ...
# 97                    Super Hotel O Madhapur VIP Hills
# 98                              Hotel Imperial Classic
# 99                              The Purple Leaf Hotels
# 100                                 The Golkonda Hotel
# 101  FabHotel Royal Residency II - Nr Metro Station...
#
#                     Location    Price             Sharing  \
# 0      HSR Layout, Bangalore   3037.0  2 nights, 2 adults
# 1                  Bangalore  23500.0  2 nights, 2 adults
# 2    Kalyan Nagar, Bangalore   3562.0  2 nights, 2 adults
# 3     Indiranagar, Bangalore   5656.0  2 nights, 2 adults
# ...

# %%
DD.to_excel("ALL HOTEL LIST[1].xlsx")

# %%
DD.to_csv("ALL HOTEL LIST[1].csv")

# %%
DD
# Out:
#                                             Hotel_Name  \
# 0                           Itsy Hotels Shree Comforts
# 1                    The Leela Bhartiya City Bengaluru
# 2              Olive Zip Kalyan Nagar by Embassy Group
# 3             Olive Hotel Indiranagar by Embassy Group
# 4                         Radisson Blu Atria Bengaluru
# ..                                                 ...
# 97                    Super Hotel O Madhapur VIP Hills
# 98                              Hotel Imperial Classic
# 99                              The Purple Leaf Hotels
# 100                                 The Golkonda Hotel
# 101  FabHotel Royal Residency II - Nr Metro Station...
#
#                     Location    Price             Sharing  \
# 0      HSR Layout, Bangalore   3037.0  2 nights, 2 adults
# 1                  Bangalore  23500.0  2 nights, 2 adults
# 2    Kalyan Nagar, Bangalore   3562.0  2 nights, 2 adults
# 3     Indiranagar, Bangalore   5656.0  2 nights, 2 adults
# ...

# %%
df=pd.read_csv(r"C:\Users\navan\OneDrive\Desktop\PROJECT\data analyst project\ALL HOTEL LIST[1].csv")
df
# Out:
#      Unnamed: 0.1                                         Hotel_Name  \
# 0               0                         Itsy Hotels Shree Comforts
# 1               1                  The Leela Bhartiya City Bengaluru
# 2               2            Olive Zip Kalyan Nagar by Embassy Group
# 3               3           Olive Hotel Indiranagar by Embassy Group
# 4               4                       Radisson Blu Atria Bengaluru
# ..            ...                                                ...
# 97             97                   Super Hotel O Madhapur VIP Hills
# 98             98                             Hotel Imperial Classic
# 99             99                             The Purple Leaf Hotels
# 100           100                                 The Golkonda Hotel
# 101           101  FabHotel Royal Residency II - Nr Metro Station...
#
#                     Location    Price             Sharing  \
# 0      HSR Layout, Bangalore   3037.0  2 nights, 2 adults
# ...

# %%
DD.drop('Unnamed: 0', axis=1, inplace=True)
DD
# Out:
#                                             Hotel_Name  \
# 0                           Itsy Hotels Shree Comforts
# 1                    The Leela Bhartiya City Bengaluru
# 2              Olive Zip Kalyan Nagar by Embassy Group
# 3             Olive Hotel Indiranagar by Embassy Group
# 4                         Radisson Blu Atria Bengaluru
# ..                                                 ...
# 97                    Super Hotel O Madhapur VIP Hills
# 98                              Hotel Imperial Classic
# 99                              The Purple Leaf Hotels
# 100                                 The Golkonda Hotel
# 101  FabHotel Royal Residency II - Nr Metro Station...
#
#                     Location    Price             Sharing  \
# 0      HSR Layout, Bangalore   3037.0  2 nights, 2 adults
# 1                  Bangalore  23500.0  2 nights, 2 adults
# 2    Kalyan Nagar, Bangalore   3562.0  2 nights, 2 adults
# 3     Indiranagar, Bangalore   5656.0  2 nights, 2 adults
# ...

# %%
print(DD.columns)
# Out:
# Index(['Hotel_Name', 'Location', 'Price', 'Sharing', 'Facilities', 'Review',
#        'Review_count', 'star_count', 'city'],
#       dtype='object')

# %%
df=pd.read_csv(r"C:\Users\navan\OneDrive\Desktop\PROJECT\data analyst project\all hotel list(1).csv")
df
# Out:
#      Unnamed: 0                                         Hotel_Name  \
# 0             0                         Itsy Hotels Shree Comforts
# 1             1                  The Leela Bhartiya City Bengaluru
# 2             2            Olive Zip Kalyan Nagar by Embassy Group
# 3             3           Olive Hotel Indiranagar by Embassy Group
# 4             4                       Radisson Blu Atria Bengaluru
# ..          ...                                                ...
# 97           97                   Super Hotel O Madhapur VIP Hills
# 98           98                             Hotel Imperial Classic
# 99           99                             The Purple Leaf Hotels
# 100         100                                 The Golkonda Hotel
# 101         101  FabHotel Royal Residency II - Nr Metro Station...
#
#                     Location    Price             Sharing  \
# 0      HSR Layout, Bangalore   3037.0  2 nights, 2 adults
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
df
# Out:
#                                             Hotel_Name  \
# 0                           Itsy Hotels Shree Comforts
# 1                    The Leela Bhartiya City Bengaluru
# 2              Olive Zip Kalyan Nagar by Embassy Group
# 3             Olive Hotel Indiranagar by Embassy Group
# 4                         Radisson Blu Atria Bengaluru
# ..                                                 ...
# 97                    Super Hotel O Madhapur VIP Hills
# 98                              Hotel Imperial Classic
# 99                              The Purple Leaf Hotels
# 100                                 The Golkonda Hotel
# 101  FabHotel Royal Residency II - Nr Metro Station...
#
#                     Location    Price             Sharing  \
# 0      HSR Layout, Bangalore   3037.0  2 nights, 2 adults
# 1                  Bangalore  23500.0  2 nights, 2 adults
# 2    Kalyan Nagar, Bangalore   3562.0  2 nights, 2 adults
# 3     Indiranagar, Bangalore   5656.0  2 nights, 2 adults
# ...

# %%
df.to_excel("all hotel list(2).xlsx")

# %%
df.to_csv("all hotel list(2).csv")

# %%
df
# Out:
#                                             Hotel_Name  \
# 0                           Itsy Hotels Shree Comforts
# 1                    The Leela Bhartiya City Bengaluru
# 2              Olive Zip Kalyan Nagar by Embassy Group
# 3             Olive Hotel Indiranagar by Embassy Group
# 4                         Radisson Blu Atria Bengaluru
# ..                                                 ...
# 97                    Super Hotel O Madhapur VIP Hills
# 98                              Hotel Imperial Classic
# 99                              The Purple Leaf Hotels
# 100                                 The Golkonda Hotel
# 101  FabHotel Royal Residency II - Nr Metro Station...
#
#                     Location    Price             Sharing  \
# 0      HSR Layout, Bangalore   3037.0  2 nights, 2 adults
# 1                  Bangalore  23500.0  2 nights, 2 adults
# 2    Kalyan Nagar, Bangalore   3562.0  2 nights, 2 adults
# 3     Indiranagar, Bangalore   5656.0  2 nights, 2 adults
# ...
